# %%
import sys
sys.path.append("/Users/xiaolihe/Documents/Computer-Vision-534/hw1")
import RunMyOCRRecognition as rmr
# %pylab inline
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Populating the interactive namespace from numpy and matplotlib

# %%
reload(rmr)
display_idx = 0
improve_idx = 1
num_k = 3 #for knn
Ypred_tests, features_tests, regionss, accuracies = rmr.main_func(['test1','test2'],['test1_gt','test2_gt'],
                                                                  display_idx, improve_idx, num_k)
# Out:
# 10
# Number of labeling components: 80
# Number of labeling components: 80
# Number of labeling components: 82
# Number of labeling components: 80
# Number of labeling components: 80
# Number of labeling components: 80
# Number of labeling components: 80
# Number of labeling components: 80
# Number of labeling components: 79
# Number of labeling components: 78
# Number of labeling components: 80
# Number of labeling components: 80
# Number of labeling components: 77
# Number of labeling components: 80
# Number of labeling components: 81
# Number of labeling components: 84
# //anaconda/lib/python2.7/site-packages/skimage/io/_plugins/matplotlib_plugin.py:77: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   warn("Float image out of standard range; displaying "
# The accuracy for training data is 0.474629
# ...

# %%
print accuracies
# Out:
# [0.38571428571428573, 0.3625]

# %%
characters = ['a','d','f','h','k','m','n','o','p','q','r','s','u','w','x','z']
for c in characters:
    print '\includegraphics[width = 0.32\linewidth]{./figures/training_images_%s_improve0.png}' %c
# Out:
# \includegraphics[width = 0.32\linewidth]{./figures/training_images_a_improve0.png}
# \includegraphics[width = 0.32\linewidth]{./figures/training_images_d_improve0.png}
# \includegraphics[width = 0.32\linewidth]{./figures/training_images_f_improve0.png}
# \includegraphics[width = 0.32\linewidth]{./figures/training_images_h_improve0.png}
# \includegraphics[width = 0.32\linewidth]{./figures/training_images_k_improve0.png}
# \includegraphics[width = 0.32\linewidth]{./figures/training_images_m_improve0.png}
# \includegraphics[width = 0.32\linewidth]{./figures/training_images_n_improve0.png}
# \includegraphics[width = 0.32\linewidth]{./figures/training_images_o_improve0.png}
# \includegraphics[width = 0.32\linewidth]{./figures/training_images_p_improve0.png}
# \includegraphics[width = 0.32\linewidth]{./figures/training_images_q_improve0.png}
# \includegraphics[width = 0.32\linewidth]{./figures/training_images_r_improve0.png}
# ...
