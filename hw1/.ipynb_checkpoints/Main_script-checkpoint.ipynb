# %%
# %reset
import sys
sys.path.append("/Users/xiaolihe/Documents/Computer-Vision-534/hw1")
import RunMyOCRRecognition as ocr
# %pylab inline
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pdb on
accs,features_tests = ocr.main({'test1','test2'},{'test1_gt','test2_gt'},0)

# %%
# ### test original fixed threshold
thr_binary = range(215,248,5)
res = []
for tb in thr_binary:
    accs,features_tests = ocr.main({'test1','test2'},{'test1_gt','test2_gt'},0,tb)
    res.append([tb,accs])

# %%
#### binary morphology
# ### test original fixed threshold
accs,features_tests = ocr.main({'test1','test2'},{'test1_gt','test2_gt'},0,100,10)

# %%
print accs
# %pdb off
# Out:
# [0.21428571428571427, 0.45]
