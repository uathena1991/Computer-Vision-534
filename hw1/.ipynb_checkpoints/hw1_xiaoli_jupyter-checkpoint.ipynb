# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from scipy.spatial.distance import cdist
from skimage.measure import label, regionprops, moments, moments_central, moments_normalized, moments_hu
from skimage import io, exposure 
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle 
import pickle
import os
import sys
sys.path.append("/Users/xiaolihe/Documents/Computer-Vision-534/hw1")
import train
reload(train)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Read image and binarization by thresholding

# %%
characters = {'a','d','f','h','k','m','n','o','p','q','r','s','u','w','x','z'}
Features = []
threshold_binary = 200
threshold_size = 5
display_idx = 1
for c in characters:
    tmp_feature = train.feature_database(c,threshold_binary,threshold_size,display_idx)
    [Features.append(t) for tf in tmp_feature]
# Out:
# Number of labeling components: 82
# Number of labeling components: 89
# Number of labeling components: 113
# Number of labeling components: 95
# Number of labeling components: 108
# Number of labeling components: 81
# Number of labeling components: 102
# Number of labeling components: 80
# Number of labeling components: 86
# Number of labeling components: 80
# Number of labeling components: 94
# Number of labeling components: 82
# Number of labeling components: 85
# Number of labeling components: 84
# Number of labeling components: 115
# Number of labeling components: 121

# %% [markdown]
# ### Extracting characters and their features

# %%
### labeling
img_label = label(img_binary, background=0)
io.imshow(img_label) 
plt.title('Labeled Image') 
io.show()
print np.amax(img_label)
# Out:
# 82

# %%
### bounding boxes and Store features in Features
regions = regionprops(img_label) 
io.imshow(img_binary)
ax = plt.gca()
threshold_size = 10
Features=[]
for props in regions:
    minr, minc, maxr, maxc = props.bbox
    if maxc - minc >= threshold_size and maxr - minr >= threshold_size:
        roi = img_binary[minr:maxr, minc:maxc] 
        m = moments(roi)
        cr = m[0, 1] / m[0, 0]
        cc = m[1, 0] / m[0, 0]
        mu = moments_central(roi, cr, cc) 
        nu = moments_normalized(mu)
        hu = moments_hu(nu)
        Features.append(hu)
        ax.add_patch(Rectangle((minc, minr), maxc - minc, maxr - minr, fill=False, edgecolor='red', linewidth=1))
ax.set_title('Bounding Boxes')
io.show()

# %% [markdown]
# ### Building Character Features Database for Recognition

# %%
os.getcwd()
# Out:
# '/Users/xiaolihe'
